# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print('Sample words', words[:10])
# Out:
# Data size 17005207
# Sample words ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.271925
# Nearest to which: psychologically, footnote, ambulatory, wilmot, exchanger, digesting, branwell, norodom,
# Nearest to if: inst, repeated, pis, frau, memoriam, implications, declensions, runoff,
# Nearest to in: panspermia, proscription, odes, japonic, usbc, electricity, siam, marysville,
# Nearest to he: conferring, disestablished, isostatic, regrouped, sequels, ramones, isla, dostoyevsky,
# Nearest to was: sauces, gearbox, infertility, hoplites, clearest, saline, mobile, elitism,
# Nearest to as: patterson, disuse, bought, attitudes, seamlessly, carnap, konami, venturi,
# Nearest to th: paralysis, ammon, dude, mature, branded, tswana, methylated, malabo,
# Nearest to will: neopagan, oncoming, headway, tops, combinatory, constitute, niall, consulting,
# Nearest to over: thriving, husbands, hostage, fig, attractive, malevolent, announce, inequality,
# Nearest to nine: unpopular, pusc, carbon, srpska, excluded, rabban, desktops, bremen,
# Nearest to four: esp, paleontology, hardware, social, jacques, disproven, moravia, titan,
# Nearest to or: richest, bedi, congo, lucian, airframe, ankobra, hoop, vieira,
# Nearest to new: north, sine, eu, investing, christianum, numismatic, legalized, expressions,
# Nearest to they: sustain, magnets, amuse, carbamazepine, uae, lion, mistreatment, swallow,
# Nearest to while: plymouth, berio, england, mammoths, textured, oren, occupancy, wy,
# Nearest to has: tarleton, solvents, thanking, launched, solitaire, tron, ghc, yeager,
# Average loss at step 2000: 4.372783
# Average loss at step 4000: 3.872336
# Average loss at step 6000: 3.787057
# Average loss at step 8000: 3.687953
# Average loss at step 10000: 3.617596
# Average loss at step 12000: 3.610466
# Average loss at step 14000: 3.569729
# Average loss at step 16000: 3.411400
# Average loss at step 18000: 3.460844
# Average loss at step 20000: 3.544065
# Nearest to which: this, that, also, but, who, it, and, these,
# Nearest to if: when, but, is, inst, pis, michal, hertogenbosch, gomorrah,
# Nearest to in: at, during, on, from, with, of, and, for,
# Nearest to he: it, they, she, who, there, bilge, yo, never,
# Nearest to was: is, were, has, had, been, apiaceae, cage, contemplating,
# Nearest to as: baird, kets, sacked, patterson, grasslands, pundits, zapatistas, applicable,
# Nearest to th: dude, branded, ammon, pentecost, griffon, perineum, methylated, tswana,
# Nearest to will: can, would, could, should, yosemite, may, to, cannot,
# Nearest to over: hostage, fig, thriving, at, attractive, husbands, achromatic, announce,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to or: and, than, jeffersonian, but, jumo, grudge, cplp, qm,
# Nearest to new: sine, expressions, investing, rhetoric, biomass, crippling, next, beans,
# Nearest to they: he, we, there, it, you, who, then, these,
# Nearest to while: and, from, maclean, textured, chisholm, into, stories, although,
# Nearest to has: had, have, was, is, hypertrophy, gonorrhea, vl, atil,
# Average loss at step 22000: 3.500052
# Average loss at step 24000: 3.490789
# Average loss at step 26000: 3.475797
# Average loss at step 28000: 3.478790
# Average loss at step 30000: 3.509997
# Average loss at step 32000: 3.505987
# Average loss at step 34000: 3.496548
# Average loss at step 36000: 3.454025
# Average loss at step 38000: 3.302687
# Average loss at step 40000: 3.432761
# Nearest to which: that, this, also, it, who, usually, there, sacher,
# Nearest to if: when, where, for, is, in, consonant, michal, that,
# Nearest to in: during, of, at, for, and, from, under, turbojet,
# Nearest to he: she, it, they, who, there, i, yo, bilge,
# Nearest to was: is, has, had, were, been, became, be, heading,
# Nearest to as: treehouse, patterson, candles, klaip, be, by, taxpayers, pepys,
# Nearest to th: dude, pentecost, astoria, volcanism, kb, methylated, five, griffon,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to over: fig, thriving, between, husbands, hostage, silvery, through, influx,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to four: six, eight, three, seven, five, two, nine, one,
# Nearest to or: and, than, belizean, gelatin, talkin, but, mapsto, kerr,
# Nearest to new: city, dissension, diddy, second, next, attainable, titular, preseason,
# Nearest to they: we, there, you, he, it, not, nationalised, i,
# Nearest to while: although, though, when, caryophyllales, rousseau, maclachlan, bitter, but,
# Nearest to has: had, have, was, is, vl, ferrari, offers, logan,
# Average loss at step 42000: 3.437831
# Average loss at step 44000: 3.452552
# Average loss at step 46000: 3.448931
# Average loss at step 48000: 3.358590
# Average loss at step 50000: 3.386011
# Average loss at step 52000: 3.438577
# Average loss at step 54000: 3.428171
# Average loss at step 56000: 3.435936
# Average loss at step 58000: 3.396029
# Average loss at step 60000: 3.398274
# Nearest to which: that, this, what, who, it, but, these, there,
# Nearest to if: when, where, though, before, while, then, since, so,
# Nearest to in: within, during, at, including, of, between, since, from,
# Nearest to he: she, it, they, there, who, eventually, initially, subsequently,
# Nearest to was: is, had, became, were, has, be, been, when,
# Nearest to as: klaip, baird, qassam, hastily, stick, when, find, diocesan,
# Nearest to th: five, dude, kb, four, six, pentecost, astoria, eight,
# Nearest to will: would, could, can, may, should, must, cannot, might,
# Nearest to over: hostage, through, into, unattested, between, outstanding, around, mandela,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to or: and, than, authorizing, but, endorsing, cowper, diatomic, galactic,
# Nearest to new: diddy, rhetoric, second, paleolithic, dissension, eats, attainable, senior,
# Nearest to they: we, there, you, he, she, it, not, i,
# Nearest to while: although, though, when, but, after, before, if, were,
# Nearest to has: had, have, is, was, shia, having, vl, stringent,
# Average loss at step 62000: 3.244649
# Average loss at step 64000: 3.249339
# Average loss at step 66000: 3.406706
# Average loss at step 68000: 3.392666
# Average loss at step 70000: 3.359914
# Average loss at step 72000: 3.374813
# Average loss at step 74000: 3.346574
# Average loss at step 76000: 3.319576
# Average loss at step 78000: 3.352290
# Average loss at step 80000: 3.379765
# Nearest to which: this, that, usually, actually, what, often, but, also,
# Nearest to if: when, before, though, where, although, since, then, requires,
# Nearest to in: during, within, until, on, at, under, since, voids,
# Nearest to he: she, it, they, who, there, never, we, eventually,
# Nearest to was: is, became, were, had, has, been, being, be,
# Nearest to as: coprime, baird, impasse, became, voids, wombat, matres, like,
# Nearest to th: dude, bc, kb, rd, twentieth, nd, pentecost, astoria,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to over: unattested, into, around, between, hostage, thriving, about, outstanding,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to or: and, while, than, plesiosaur, gelatin, masks, jumo, mediation,
# Nearest to new: raisonn, desolation, dactyl, martens, modern, different, old, diddy,
# Nearest to they: we, he, you, there, it, she, however, these,
# Nearest to while: although, and, when, though, after, before, however, or,
# Nearest to has: had, is, have, was, kr, stringent, since, contains,
# Average loss at step 82000: 3.408114
# Average loss at step 84000: 3.408068
# Average loss at step 86000: 3.388550
# Average loss at step 88000: 3.349416
# Average loss at step 90000: 3.365133
# Average loss at step 92000: 3.400150
# Average loss at step 94000: 3.254710
# Average loss at step 96000: 3.359177
# Average loss at step 98000: 3.239820
# Average loss at step 100000: 3.361724
# Nearest to which: that, this, usually, actually, what, but, it, often,
# Nearest to if: when, where, before, though, while, requires, know, although,
# Nearest to in: within, during, throughout, on, until, at, from, into,
# Nearest to he: she, it, they, there, who, we, never, initially,
# Nearest to was: is, became, has, had, were, been, when, being,
# Nearest to as: when, qassam, like, auc, radically, baird, nicole, smallville,
# Nearest to th: dude, nd, bc, pentecost, rd, karate, upanishads, astoria,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to over: through, neoplatonism, thriving, around, into, between, unattested, socialists,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to four: six, five, seven, eight, two, three, nine, zero,
# Nearest to or: and, than, grudge, manuel, bower, without, grahame, damper,
# Nearest to new: yokoi, raisonn, dactyl, graduate, biomass, tourist, fictional, different,
# Nearest to they: we, he, there, you, she, it, i, autoimmune,
# Nearest to while: although, when, though, before, after, and, but, if,
# Nearest to has: had, have, is, was, since, having, metamorphosis, stringent,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_cbow_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ skip_window target skip_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2, 3, 4]:
  data_index = 0
  batch, labels = generate_cbow_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']
#
# with bag_window = 3:
#     batch: [['anarchism', 'originated', 'as', 'term', 'of', 'abuse'], ['originated', 'as', 'a', 'of', 'abuse', 'first'], ['as', 'a', 'term', 'abuse', 'first', 'used'], ['a', 'term', 'of', 'first', 'used', 'against']]
#     labels: ['a', 'term', 'of', 'abuse']
#
# with bag_window = 4:
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']]
#     labels: ['term', 'of', 'abuse', 'first']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 20000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.963309
# Nearest to by: zimbabwean, flannery, steam, jade, wapping, loneliness, assay, settings,
# Nearest to first: astonishing, presidential, drains, brokerage, knots, gigabit, nol, doggy,
# Nearest to been: grampus, compresses, fluency, anchoring, whatsoever, transfinite, polisario, baba,
# Nearest to war: widehat, herndon, qualitative, shoots, dismiss, beets, tyrant, manually,
# Nearest to these: puritanism, adjutant, cruciform, patented, xico, tera, centerpiece, bethune,
# Nearest to its: dq, pierluigi, vi, lebanon, ribera, unmibh, sam, scooby,
# Nearest to only: manama, lott, paragraph, inks, blica, revolvers, rampart, slur,
# Nearest to more: ccr, duals, firewall, fontainebleau, thoroughly, asgard, airbases, amherst,
# Nearest to some: foci, typologically, emphatic, smithers, keypad, netware, grampus, shandy,
# Nearest to of: scalloped, canisters, biosynthesis, butler, blaxploitation, mundo, gerard, dweller,
# Nearest to up: uzziah, administrators, superscription, cocalus, faye, hutu, horribilis, fluorescent,
# Nearest to may: adequate, khans, vii, ebola, spelt, essequibo, osu, landsat,
# Nearest to th: shrapnel, simo, prowess, almohades, brazil, amhara, counselors, apoptosis,
# Nearest to most: sextus, bounding, illustrations, ene, boulevards, cha, reconquest, pashtuns,
# Nearest to often: mph, corum, mazzola, fibre, potable, stabilizer, katzenjammer, differential,
# Nearest to he: wrestlers, ulster, hm, cody, impresario, matters, regis, xena,
# Average loss at step 2000: 4.580514
# Average loss at step 4000: 3.951659
# Average loss at step 6000: 3.721504
# Average loss at step 8000: 3.530316
# Average loss at step 10000: 3.473828
# Average loss at step 12000: 3.485313
# Average loss at step 14000: 3.437927
# Average loss at step 16000: 3.435124
# Average loss at step 18000: 3.401418
# Average loss at step 20000: 3.220247
# Nearest to by: flashes, guez, lethargy, outspoken, when, richmond, woodbridge, mosaics,
# Nearest to first: last, next, second, ww, fourth, same, feudalism, positives,
# Nearest to been: become, come, turbines, hypnotherapy, gregg, gavin, pri, confidentiality,
# Nearest to war: widehat, helpdesk, overpowered, positives, cain, stumbling, circumcision, albanians,
# Nearest to these: various, they, many, several, some, different, estas, all,
# Nearest to its: their, his, the, her, spill, underwood, sorting, cadet,
# Nearest to only: first, no, still, peaked, utilization, contours, did, homing,
# Nearest to more: less, rather, most, greater, better, very, gelatinous, astrological,
# Nearest to some: many, both, several, all, various, any, most, certain,
# Nearest to of: blaze, against, shaivism, hoses, among, in, akihito, ncbi,
# Nearest to up: out, back, them, dato, caricatures, phenomenal, down, brokered,
# Nearest to may: can, would, could, will, should, must, might, cannot,
# Nearest to th: st, nd, nine, stamp, gilmour, referendum, bretagne, pala,
# Nearest to most: more, some, many, iberian, reemergence, very, prescription, doggy,
# Nearest to often: sometimes, generally, usually, commonly, widely, still, also, frequently,
# Nearest to he: she, it, who, they, supposedly, dearth, hampered, ataxia,
# Average loss at step 22000: 3.365206
# Average loss at step 24000: 3.285847
# Average loss at step 26000: 3.254875
# Average loss at step 28000: 3.278266
# Average loss at step 30000: 3.233690
# Average loss at step 32000: 3.013503
# Average loss at step 34000: 3.205847
# Average loss at step 36000: 3.190632
# Average loss at step 38000: 3.141927
# Average loss at step 40000: 3.156232
# Nearest to by: from, using, have, among, draught, gino, federation, has,
# Nearest to first: last, next, second, best, third, same, fourth, earliest,
# Nearest to been: become, come, remained, hypnotherapy, gavin, begun, thursday, multiplies,
# Nearest to war: wars, deceleration, helpdesk, widehat, victories, fathoms, dismiss, conformed,
# Nearest to these: various, different, several, those, both, certain, winn, bangla,
# Nearest to its: their, his, your, her, the, akademie, our, sorting,
# Nearest to only: pyongyang, universally, knots, still, isa, next, homomorphisms, allied,
# Nearest to more: less, rather, greater, larger, most, very, better, faster,
# Nearest to some: many, several, various, those, both, most, numerous, certain,
# Nearest to of: logitech, baleen, busman, sleepy, during, famagusta, thrush, cayley,
# Nearest to up: off, out, down, back, bolsheviks, relative, caricatures, them,
# Nearest to may: could, would, can, will, must, might, should, cannot,
# Nearest to th: st, twentieth, nd, unscientific, stamp, seventeenth, hing, caching,
# Nearest to most: more, some, less, first, best, prescription, clearest, mayhew,
# Nearest to often: sometimes, usually, commonly, generally, frequently, widely, typically, still,
# Nearest to he: she, it, they, designing, defiant, tiryns, hampered, sinner,
# Average loss at step 42000: 3.205158
# Average loss at step 44000: 3.139280
# Average loss at step 46000: 3.137468
# Average loss at step 48000: 3.058450
# Average loss at step 50000: 3.060906
# Average loss at step 52000: 3.093391
# Average loss at step 54000: 3.099024
# Average loss at step 56000: 2.922678
# Average loss at step 58000: 3.023299
# Average loss at step 60000: 3.044692
# Nearest to by: under, including, through, cuon, aquarists, within, toward, flashes,
# Nearest to first: last, second, next, earliest, third, best, latter, fourth,
# Nearest to been: become, come, remained, resulted, gone, appeared, listened, increased,
# Nearest to war: wars, herndon, positives, cain, dismiss, fathoms, blessings, entries,
# Nearest to these: various, numerous, all, certain, several, many, different, both,
# Nearest to its: their, his, her, the, your, our, letterboxes, sacks,
# Nearest to only: still, she, actually, he, always, no, germ, pharos,
# Nearest to more: less, rather, very, greater, better, larger, most, smaller,
# Nearest to some: many, several, various, numerous, most, all, certain, both,
# Nearest to of: fullerton, thrush, in, following, positivism, cryptographers, busman, including,
# Nearest to up: off, out, back, coffins, them, maimon, coliseum, down,
# Nearest to may: can, might, should, could, must, would, will, cannot,
# Nearest to th: nd, st, twentieth, third, seventeenth, kierkegaard, rd, second,
# Nearest to most: more, some, many, especially, less, particularly, all, very,
# Nearest to often: frequently, commonly, sometimes, usually, generally, widely, typically, currently,
# Nearest to he: she, it, they, who, isolates, only, this, fitzroy,
# Average loss at step 62000: 3.007760
# Average loss at step 64000: 2.916578
# Average loss at step 66000: 2.933168
# Average loss at step 68000: 2.968388
# Average loss at step 70000: 3.007011
# Average loss at step 72000: 2.942994
# Average loss at step 74000: 2.871345
# Average loss at step 76000: 2.997772
# Average loss at step 78000: 3.004741
# Average loss at step 80000: 2.854284
# Nearest to by: when, ensued, straddles, without, among, aquarists, toward, who,
# Nearest to first: last, next, second, earliest, same, third, best, latter,
# Nearest to been: become, come, remained, resulted, occurred, increased, fallen, appeared,
# Nearest to war: wars, campaign, differed, helpdesk, dismiss, balto, corridors, fathoms,
# Nearest to these: various, certain, those, different, numerous, several, multiple, other,
# Nearest to its: their, his, her, the, your, sacks, letterboxes, whose,
# Nearest to only: always, necessarily, it, monotone, fully, goldbach, least, still,
# Nearest to more: less, very, rather, most, better, greater, relatively, quite,
# Nearest to some: many, several, various, numerous, certain, those, all, most,
# Nearest to of: including, while, include, aliases, in, thrush, baleen, nada,
# Nearest to up: off, down, out, bolsheviks, back, severed, together, erupts,
# Nearest to may: might, can, could, should, would, will, must, cannot,
# Nearest to th: nd, twentieth, nineteenth, seventeenth, rd, st, unscientific, third,
# Nearest to most: more, some, many, less, greatest, all, principal, earliest,
# Nearest to often: sometimes, frequently, commonly, usually, generally, widely, typically, traditionally,
# Nearest to he: she, it, they, sinner, isolates, ford, harmattan, siddhartha,
# Average loss at step 82000: 2.938792
# Average loss at step 84000: 2.907720
# Average loss at step 86000: 2.916620
# Average loss at step 88000: 2.938131
# Average loss at step 90000: 2.827998
# Average loss at step 92000: 2.892569
# Average loss at step 94000: 2.885930
# Average loss at step 96000: 2.709490
# Average loss at step 98000: 2.459804
# Average loss at step 100000: 2.701669
# Nearest to by: toward, through, actually, flashes, from, unsteady, without, straddles,
# Nearest to first: last, next, second, earliest, third, best, greatest, final,
# Nearest to been: become, fallen, come, grown, resulted, gone, occurred, remained,
# Nearest to war: wars, fathoms, calendars, victories, campaign, enzymatic, dismiss, mamertines,
# Nearest to these: various, other, certain, those, different, multiple, numerous, many,
# Nearest to its: their, his, her, the, your, our, whose, letterboxes,
# Nearest to only: always, entirely, oldest, first, yet, flirty, fifth, last,
# Nearest to more: less, rather, quite, most, very, greater, better, faster,
# Nearest to some: many, several, numerous, various, both, certain, all, this,
# Nearest to of: baleen, namespace, cryptographers, hee, represents, thrush, fullerton, busman,
# Nearest to up: off, out, together, down, forth, pesticides, bolsheviks, caricatures,
# Nearest to may: might, should, can, could, must, would, cannot, will,
# Nearest to th: nd, twentieth, seventeenth, fourth, eighteenth, nineteenth, fifth, rd,
# Nearest to most: more, particularly, many, first, less, some, best, greatest,
# Nearest to often: sometimes, usually, frequently, typically, commonly, generally, traditionally, primarily,
# Nearest to he: she, it, they, who, initially, quickly, siddhartha, deutschlands,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
